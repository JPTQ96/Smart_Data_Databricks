-- %%
GRANT USE CATALOG ON CATALOG catalog_jptq TO `juanpis602@hotmail.com`;

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_jptq.bronze_jptq TO `juanpis602@hotmail.com`;
GRANT USE SCHEMA ON SCHEMA catalog_jptq.silver_jptq TO `juanpis602@hotmail.com`;
GRANT USE SCHEMA ON SCHEMA catalog_jptq.golden_jptq TO `juanpis602@hotmail.com`;

-- %%
GRANT SELECT ON TABLE catalog_jptq.bronze_jptq.tbl_detalle_peliculas TO `juanpis602@hotmail.com`;
GRANT SELECT ON TABLE catalog_jptq.bronze_jptq.tbl_mas_info_peliculas TO `juanpis602@hotmail.com`;
GRANT SELECT ON TABLE catalog_jptq.bronze_jptq.tbl_peliculas TO `juanpis602@hotmail.com`;
GRANT SELECT ON TABLE catalog_jptq.bronze_jptq.tbl_poster_peliculas TO `juanpis602@hotmail.com`;

-- %%
GRANT SELECT ON TABLE catalog_jptq.silver_jptq.tbl_tmp_director_pelicula TO `juanpis602@hotmail.com`;
GRANT SELECT ON TABLE catalog_jptq.silver_jptq.tbl_tmp_genero_pelicula TO `juanpis602@hotmail.com`;
GRANT SELECT ON TABLE catalog_jptq.silver_jptq.tbl_tmp_idioma_pelicula TO `juanpis602@hotmail.com`;
GRANT SELECT ON TABLE catalog_jptq.silver_jptq.tbl_tmp_pelicula TO `juanpis602@hotmail.com`;

-- %%
GRANT SELECT ON TABLE catalog_jptq.golden_jptq.tbl_dim_director_pelicula_t2 TO `juanpis602@hotmail.com`;
GRANT SELECT ON TABLE catalog_jptq.golden_jptq.tbl_dim_genero_pelicula_t0 TO `juanpis602@hotmail.com`;
GRANT SELECT ON TABLE catalog_jptq.golden_jptq.tbl_dim_idioma_pelicula_t0 TO `juanpis602@hotmail.com`;
GRANT SELECT ON TABLE catalog_jptq.golden_jptq.tbl_dim_pelicula_t1 TO `juanpis602@hotmail.com`;
GRANT SELECT ON TABLE catalog_jptq.golden_jptq.tbl_fct_pelicula TO `juanpis602@hotmail.com`;

-- %%
GRANT ALL PRIVILEGES
ON EXTERNAL LOCATION `exlt-raw-jptq`
TO `juanpis602@hotmail.com`;

-- %%
GRANT ALL PRIVILEGES
ON EXTERNAL LOCATION `exlt-unity-catalog-jptq`
TO `juanpis602@hotmail.com`;
