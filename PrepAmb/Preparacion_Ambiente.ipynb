# %%
# %python
dbutils.widgets.removeAll()

# %%
# %sql
create widget text nameDatalake default "adlsjptq0126";

# %%
# %sql
CREATE CATALOG IF NOT EXISTS catalog_jptq
MANAGED LOCATION 'abfss://unity-catalog-jptq@${nameDatalake}.dfs.core.windows.net/';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS catalog_jptq.raw_jptq;
CREATE SCHEMA IF NOT EXISTS catalog_jptq.bronze_jptq;
CREATE SCHEMA IF NOT EXISTS catalog_jptq.silver_jptq;
CREATE SCHEMA IF NOT EXISTS catalog_jptq.golden_jptq;

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-raw-jptq`
URL 'abfss://raw-jptq@${nameDatalake}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential_dljptq)
COMMENT 'Ubicación externa para las tablas raw del Data Lake';

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-unity-catalog-jptq`
URL 'abfss://unity-catalog-jptq@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential_dljptq)
COMMENT 'Ubicación externa para las tablas unit-catalog del Data Lake';
